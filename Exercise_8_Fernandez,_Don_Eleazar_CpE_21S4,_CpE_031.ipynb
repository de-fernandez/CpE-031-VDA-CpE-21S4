# %% [markdown]
# <a href="https://colab.research.google.com/github/de-fernandez/CpE-031-VDA-CpE-21S4/blob/main/Exercise_8_Fernandez%2C_Don_Eleazar_CpE_21S4%2C_CpE_031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > <h1> Exercise 8 </h1>

# %%
pip install pandas

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Draw a line in a diagram from posiition (1, 3) to position (8, 10)

# %%
xpoints = np.array([1, 3])
ypoints = np.array([8, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Plotting without line
# - To plot only the markers, 'o' means 'rings'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# Multiple Points

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Format String FMT

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, 'o:y')
plt.show()

# %% [markdown]
# Marker Size

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:b', ms = 20)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:b', ms = 10, mec = 'r')
plt.show()

# %% [markdown]
# Marker Face Color

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:b', ms = 10, mec = 'green', mfc = 'red')
plt.show()

# %% [markdown]
# Dashed Line

# %%
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# Matplot Label and Title - You can use xlabel() and ylabel()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, color = 'blue')

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in Km")
plt.ylabel("Speed in Km/s")
plt.show()

# %% [markdown]
# Matplot Grid - You can use grid() to add grid lines

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, color = 'blue')

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in Km")
plt.ylabel("Speed in Km/s")
plt.grid()
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, color = 'blue')

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in Km")
plt.ylabel("Speed in Km/s")
plt.grid(axis = 'y')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints, color = 'blue')

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in Km")
plt.ylabel("Speed in Km/s")
plt.grid(axis = 'x', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# Show Multiple Plots

# %%
#PLot 1
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(xpoints, ypoints)

#Plot 2
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(xpoints, ypoints)

plt.grid(axis = 'x', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# Matplot Scatter = The scatter function plots one dot for each observation

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.scatter(xpoints, ypoints)

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])

plt.scatter(xpoints, ypoints)
plt.show()

# %% [markdown]
# Matplotlib Bars
# - You can use the bar() to draw bars

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['Student1', 'Student2', 'Student3'])
y = np.array([90, 85, 86])
plt.bar(x, y)
plt.show()

# %% [markdown]
# Matplotlib Pie Chart - You can use pie() to draw pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

g = np.array([35, 25, 25, 15])
grader = ["Grade 1 = 35%", "Grade 2 = 25%", "Grade 3 = 25%", "Grade 4 = 15%"]
plt.pie(g, labels = grader)
plt.legend(title = "Grader", labels = grader)
plt.show()

# %% [markdown]
# > <h1> Laboratory: Introduction to Matplot </h1>

# %% [markdown]
# Part 1:

# %%
#Line Plot
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
#Scatter Plot
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X - Axis")
plt.ylabel("Y - Axis")
plt.show()

# %%
#Histogram
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 4]
plt.hist(data)
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
#Bar Chart
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C']
values = [5, 7, 3]
plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
#Box Plot
import matplotlib.pyplot as plt

data = [[1.5]*10 + [2]*10 + [3]*10]
plt.boxplot(data)
plt.title("Box Plot Example")
plt.ylabel("Values")
plt.show()

# %%
#Pie Chart
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
sizes = [40, 30, 30]
plt.pie(sizes, labels = labels)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# Part 2:

# %%
#Find a dataset for this activity
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-db8ef6de-c539-42b4-8e2a-5aae59495b66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db8ef6de-c539-42b4-8e2a-5aae59495b66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Creating a dataframe from your CSV file
data = pd.read_csv('ai_job_market_insights - AI Job Market Insights.csv')
df = pd.DataFrame(data)
df
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills    Salary_USD  \
# ...

# %%
#Import the matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
#Based on your chosen dataset, you will develop three questions that you will answer using pyplot visualizations.
#This means that you will need to produce at least three pyplot visualizations.
#You are also required to make certain customizations on your data vizes.

import matplotlib.pyplot as plt

industry = df['Industry'].value_counts()
plt.figure(figsize = (10, 6))
industry.plot(kind = 'pie')
plt.title('Distribution of Jobs by Industry')
plt.legend(labels = industry, loc = "upper right", bbox_to_anchor = (1.3, 0.9))
plt.xlabel('Industry')
plt.ylabel('Number of Jobs')
plt.xticks(rotation = 90)
plt.show()

# %%
import matplotlib.pyplot as plt

skills = df['Required_Skills'].value_counts()
plt.figure(figsize = (10, 6))
skills.plot(kind = 'bar')
plt.title('Distribution of Jobs by Required Skills')
plt.xlabel('Skills')
plt.ylabel('Number of Jobs')
plt.xticks(rotation = 90)
plt.show()

# %%
import matplotlib.pyplot as plt

risk = df[['Job_Title', 'Automation_Risk']]
plt.figure(figsize = (10, 6))
risk.groupby('Job_Title')['Automation_Risk'].value_counts().unstack().plot(kind = 'bar', stacked = True)
plt.title('Automation Risk per Job')
plt.xlabel('Job Title')
plt.ylabel('Frequency of Automation Risk')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()
