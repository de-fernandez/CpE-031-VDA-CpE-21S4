# %% [markdown]
# <a href="https://colab.research.google.com/github/de-fernandez/CpE-031-VDA-CpE-21S4/blob/main/Exercise_7_Fernandez%2C_Don_Eleazar_CpE_21S4%2C_CpE_031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > <h1> Exercise 7 </h1>

# %%
pip install pandas

# %%
import pandas as pd

data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

purchases = pd.DataFrame(data)
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index = ['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')
purchases.to_excel('fruits.xlsx')

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4df3196d-3406-46da-aac0-3c20efcb25f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4df3196d-3406-46da-aac0-3c20efcb25f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('fruits.csv')
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
#Loading the data from excel file
data = pd.read_excel('fruits.xlsx')
purchases = pd.DataFrame(data)
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data.head(3)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7

# %%
data.tail(3)
# Out:
#   Unnamed: 0  apples  oranges
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %% [markdown]
# > <h1> Laboratory: Creating and Accessing Panda DataFrames </h1>

# %%
#Loading your dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-120bf60e-afbb-4704-a473-3d17bce38e8a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-120bf60e-afbb-4704-a473-3d17bce38e8a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Creating a dataframe from your CSV file
data = pd.read_csv('ai_job_market_insights - (Tab 2) AI Job Market Insights.csv')
data
# Out:
#                  Job_Title            Industry Company_Size   Location  \
# 0    Cybersecurity Analyst       Entertainment        Small      Dubai
# 1     Marketing Specialist          Technology        Large  Singapore
# 2            AI Researcher          Technology        Large  Singapore
# 3            Sales Manager              Retail        Small     Berlin
# 4    Cybersecurity Analyst       Entertainment        Small      Tokyo
# ..                     ...                 ...          ...        ...
# 495         Data Scientist  Telecommunications       Medium     Berlin
# 496  Cybersecurity Analyst  Telecommunications        Small     London
# 497  Cybersecurity Analyst              Energy        Large      Dubai
# 498     Operations Manager          Healthcare        Large      Paris
# 499             HR Manager       Entertainment       Medium     Berlin
#
#     AI_Adoption_Level Automation_Risk     Required_Skills    Salary_USD  \
# ...

# %%
#Creating a dataframe from a dictionary of lists
data_dict = { #Observation: With the tolist() function, the data on each variable has been listed according to their variable
    'Job_Title': df['Job_Title'].tolist(),
              #Observation: The Job Title data is listed
    'Industry': df['Industry'].tolist(),
              #Observation: The Industry data is listed
    'Company_Size': df['Company_Size'].tolist(),
    'Location': df['Location'].tolist(),
    'AI_Adoption_Level': df['AI_Adoption_Level'].tolist(),
    'Automation_Risk': df['Automation_Risk'].tolist(),
    'Required_Skills': df['Required_Skills'].tolist(),
    'Salary_USD': df['Salary_USD'].tolist(),
    'Remote_Friendly': df['Remote_Friendly'].tolist(),
    'Job_Growth_Projection': df['Job_Growth_Projection'].tolist(),
} #Observation: The data of each variable has been listed to the dictionary

data_2 = pd.DataFrame(data_dict) #Observation: The data on the dictionary has been placed to a data frame

# %%
#Creating a dataframe from a list of dictionaries
import pandas as pd

#Observation: Manually create a list of dictionaries
data = [
    {"Job_Title": "Cybersecurity Analyst", "Industry": "Entertainment", "Company_Size": "Small", "Location": "Dubai", "AI_Adoption_Level": "Medium", "Automation_Risk": "High", "Required_Skills": "UX/UI Design", "Salary_USD": 111392.1652, "Remote_Friendly": "Yes", "Job_Growth_Projection": "Growth"},
    {"Job_Title": "Marketing Specialist", "Industry": "Technology", "Company_Size": "Large", "Location": "Singapore", "AI_Adoption_Level": "Medium", "Automation_Risk": "High", "Required_Skills": "Marketing", "Salary_USD": 93792.56247, "Remote_Friendly": "No", "Job_Growth_Projection": "Decline"},
    {"Job_Title": "AI Researcher", "Industry": "Technology", "Company_Size": "Large", "Location": "Singapore", "AI_Adoption_Level": "Medium", "Automation_Risk": "High", "Required_Skills": "UX/UI Design", "Salary_USD": 107170.2631, "Remote_Friendly": "Yes", "Job_Growth_Projection": "Growth"},
    {"Job_Title": "Sales Manager", "Industry": "Retail", "Company_Size": "Small", "Location": "Berlin", "AI_Adoption_Level": "Low", "Automation_Risk": "High", "Required_Skills": "Project Management", "Salary_USD": 93027.95376, "Remote_Friendly": "No", "Job_Growth_Projection": "Growth"},
    {"Job_Title": "Cybersecurity Analyst", "Industry": "Entertainment", "Company_Size": "Small", "Location": "Tokyo", "AI_Adoption_Level": "Low", "Automation_Risk": "Low", "Required_Skills": "JavaScript", "Salary_USD": 87752.92217, "Remote_Friendly": "Yes", "Job_Growth_Projection": "Decline"}
] #Observation: The list of dictionaries

#Observation: Create a data frame from the list of dictionaries
#Observation: Passing the list of dictionaries into a new data frame
df = pd.DataFrame(data)
df #Observation: The printing of the data
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
# 2          AI Researcher     Technology        Large  Singapore
# 3          Sales Manager         Retail        Small     Berlin
# 4  Cybersecurity Analyst  Entertainment        Small      Tokyo
#
#   AI_Adoption_Level Automation_Risk     Required_Skills    Salary_USD  \
# 0            Medium            High        UX/UI Design  111392.16520
# 1            Medium            High           Marketing   93792.56247
# 2            Medium            High        UX/UI Design  107170.26310
# 3               Low            High  Project Management   93027.95376
# 4               Low             Low          JavaScript   87752.92217
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
# ...

# %%
#Selecting dataframe columns
single_column = df['Job_Title']
single_column
# Out:
# 0    Cybersecurity Analyst
# 1     Marketing Specialist
# 2            AI Researcher
# 3            Sales Manager
# 4    Cybersecurity Analyst
# Name: Job_Title, dtype: object

# %%
multiple_columns = df[['Job_Title', 'Industry', 'Company_Size']]
multiple_columns
# Out:
#                Job_Title       Industry Company_Size
# 0  Cybersecurity Analyst  Entertainment        Small
# 1   Marketing Specialist     Technology        Large
# 2          AI Researcher     Technology        Large
# 3          Sales Manager         Retail        Small
# 4  Cybersecurity Analyst  Entertainment        Small

# %%
#Selecting dataframe rows (Using Pandas Indexing)
single_row = df.loc[0]
single_row
# Out:
# Job_Title                Cybersecurity Analyst
# Industry                         Entertainment
# Company_Size                             Small
# Location                                 Dubai
# AI_Adoption_Level                       Medium
# Automation_Risk                           High
# Required_Skills                   UX/UI Design
# Salary_USD                         111392.1652
# Remote_Friendly                            Yes
# Job_Growth_Projection                   Growth
# Name: 0, dtype: object

# %%
# (Using Pandas Indexing)
multiple_row = df.loc[0:1]
multiple_row
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
#
#   AI_Adoption_Level Automation_Risk Required_Skills    Salary_USD  \
# 0            Medium            High    UX/UI Design  111392.16520
# 1            Medium            High       Marketing   93792.56247
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline

# %%
# (Using Python Indexing)
single_row = df[0:1]
single_row
# Out:
#                Job_Title       Industry Company_Size Location  \
# 0  Cybersecurity Analyst  Entertainment        Small    Dubai
#
#   AI_Adoption_Level Automation_Risk Required_Skills   Salary_USD  \
# 0            Medium            High    UX/UI Design  111392.1652
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth

# %%
# (Using Python Indexing)
multiple_row = df[0:2]
multiple_row
# Out:
#                Job_Title       Industry Company_Size   Location  \
# 0  Cybersecurity Analyst  Entertainment        Small      Dubai
# 1   Marketing Specialist     Technology        Large  Singapore
#
#   AI_Adoption_Level Automation_Risk Required_Skills    Salary_USD  \
# 0            Medium            High    UX/UI Design  111392.16520
# 1            Medium            High       Marketing   93792.56247
#
#   Remote_Friendly Job_Growth_Projection
# 0             Yes                Growth
# 1              No               Decline
